# %%
import numpy as np
import pandas as pd
import scipy.stats as st
import matplotlib.pyplot as plt
import seaborn as sns
import openpyxl

# %%
df = pd.read_excel(r"C:\Users\user1\Documents\School\TUC\Statistik\data\HR_Employee_Data.xlsx")

# %%
df.describe
# Out:
# <bound method NDFrame.describe of          Emp_Id  satisfaction_level  last_evaluation  number_project  \
# 0      IND02438                0.38             0.53               2
# 1      IND28133                0.80             0.86               5
# 2      IND07164                0.11             0.88               7
# 3      IND30478                0.72             0.87               5
# 4      IND24003                0.37             0.52               2
# ...         ...                 ...              ...             ...
# 14994  IND40221                0.40             0.57               2
# 14995  IND24196                0.37             0.48               2
# 14996  IND33544                0.37             0.53               2
# 14997  IND40533                0.11             0.96               6
# 14998  IND11649                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# ...

# %%
df.head()
# Out:
#      Emp_Id  satisfaction_level  last_evaluation  number_project  \
# 0  IND02438                0.38             0.53               2
# 1  IND28133                0.80             0.86               5
# 2  IND07164                0.11             0.88               7
# 3  IND30478                0.72             0.87               5
# 4  IND24003                0.37             0.52               2
#
#    average_montly_hours  time_spend_company  Work_accident  left  \
# 0                   157                   3              0     1
# 1                   262                   6              0     1
# 2                   272                   4              0     1
# 3                   223                   5              0     1
# 4                   159                   3              0     1
#
#    promotion_last_5years Department  salary
# 0                      0      sales     low
# 1                      0      sales  medium
# 2                      0      sales  medium
# ...

# %%
df.dtypes
# Out:
# Emp_Id                    object
# satisfaction_level       float64
# last_evaluation          float64
# number_project             int64
# average_montly_hours       int64
# time_spend_company         int64
# Work_accident              int64
# left                       int64
# promotion_last_5years      int64
# Department                object
# salary                    object
# dtype: object

# %%
sns.barplot(data=df, x="Department", y="satisfaction_level")
# Out:
# <Axes: xlabel='Department', ylabel='satisfaction_level'>

# %%
plot1 = sns.barplot(data=df, x="Department", y="satisfaction_level")
plot1.set_xticklabels(plot1.get_xticklabels(), rotation=45)
# Out:
# C:\Users\user1\AppData\Local\Temp\ipykernel_15832\2068368380.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plot1.set_xticklabels(plot1.get_xticklabels(), rotation=45)
# [Text(0, 0, 'sales'),
#  Text(1, 0, 'accounting'),
#  Text(2, 0, 'hr'),
#  Text(3, 0, 'technical'),
#  Text(4, 0, 'support'),
#  Text(5, 0, 'management'),
#  Text(6, 0, 'IT'),
#  Text(7, 0, 'product_mng'),
#  Text(8, 0, 'marketing'),
#  Text(9, 0, 'RandD')]

# %%
plot2 = sns.boxplot(data=df, x="Department", y="satisfaction_level")
plot2.set_xticklabels(plot2.get_xticklabels(), rotation=45)
# Out:
# C:\Users\user1\AppData\Local\Temp\ipykernel_15832\953851796.py:2: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plot2.set_xticklabels(plot2.get_xticklabels(), rotation=45)
# [Text(0, 0, 'sales'),
#  Text(1, 0, 'accounting'),
#  Text(2, 0, 'hr'),
#  Text(3, 0, 'technical'),
#  Text(4, 0, 'support'),
#  Text(5, 0, 'management'),
#  Text(6, 0, 'IT'),
#  Text(7, 0, 'product_mng'),
#  Text(8, 0, 'marketing'),
#  Text(9, 0, 'RandD')]

# %%
sns.scatterplot(data=df, x="Department", y="last_evaluation")
# Out:
# <Axes: xlabel='Department', ylabel='last_evaluation'>

# %%
plt.scatter(df["last_evaluation"], df["satisfaction_level"], colorizer="m")

# %%
hr_pos = df[]
